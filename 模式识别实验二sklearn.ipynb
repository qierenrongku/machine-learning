# %%
# 导入基本库
import numpy as np
from numpy import genfromtxt
from sklearn import linear_model
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
# 读入数据
data=pd.read_csv("Delivery.csv")

# %%
data
# Out:
#    100  4  9.3
# 0   50  3  4.8
# 1  100  4  8.9
# 2  100  2  6.5
# 3   50  2  4.2
# 4   80  2  6.2
# 5   75  3  7.4
# 6   65  4  6.0
# 7   90  3  7.6
# 8   90  2  6.1

# %%
# 划分数据
xdata=data.iloc[:,:2]
ydata=data.iloc[:,-1]

# %%
xdata
# Out:
#    100  4
# 0   50  3
# 1  100  4
# 2  100  2
# 3   50  2
# 4   80  2
# 5   75  3
# 6   65  4
# 7   90  3
# 8   90  2

# %%
ydata
# Out:
# 0    4.8
# 1    8.9
# 2    6.5
# 3    4.2
# 4    6.2
# 5    7.4
# 6    6.0
# 7    7.6
# 8    6.1
# Name: 9.3, dtype: float64

# %%
# 建立模型
lm=linear_model.LinearRegression()
lm.fit(xdata,ydata)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# 参数
lm.coef_
# Out:
# array([0.05847613, 0.84415239])

# %%
# 截距
lm.intercept_
# Out:
# -0.48189985027449644

# %%
# 画图
x0=xdata.iloc[:,0]
x1=xdata.iloc[:,1]
ax=plt.figure().add_subplot(111,projection="3d")
ax.scatter(x0,x1,ydata,c='r',marker='o',s=200)
x0,x1=np.meshgrid(x0,x1)
z=lm.intercept_+x0*lm.coef_[0]+x1*lm.coef_[1]
ax.plot_surface(x0,x1,z,alpha=0.2)
plt.show()
